# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime
import re

# %%
# set up YouTube Data API 
api_key = "AIzaSyB4rEWrBMhi4lJEgfwsV386f44qwL3HxG4"
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
brands = ["Shein", "Princess Polly", "Brandy Melville", "Nike"]
published_after = datetime(2023, 1, 1).isoformat() + 'Z'
published_before = datetime(2023, 12, 31).isoformat() + 'Z'

# %%
# search for videos
search_response = youtube.search().list(
    q=' '.join(brands),  # combine keywords into single query string
    part='snippet',
    type='video',
    publishedAfter=published_after,
    publishedBefore=published_before,
    maxResults=30
).execute()

# %%
videos = []
for search_result in search_response.get('items', []):
    # gets and stores video id
    video_id = search_result['id']['videoId']
    video_response = youtube.videos().list(
        # receive snippet part of data - title, description, tags, etc.
        part="snippet",
        id=video_id
    ).execute()

    # accesses description field of snipper
    description = video_response['items'][0]['snippet']['description']
    
    # extract links from description
    links = re.findall(r'(https?://\S+)', description)
    
    # add video title, description, and links (if there are links) to videos list
    videos.append({
        'title': search_result['snippet']['title'],
        # 'description': description,
        # 'publish_time': search_result['snippet']['publishedAt'],
        # 'video_id': video_id,
        'links': links
    })

# %%
# filter vids into separate lists based on BRANDS
filtered_vids_brands = {}

for brand in brands:
    filtered_vids_brands[brand] = [
        video for video in videos 
        if brand.lower() in video['title'].lower() and video['links']
    ]
for brand, vid_list in filtered_vids_brands.items():
    print(f"VIDEOS WITH '{brand}':")
    for video in vid_list:
        print("title:", video['title'])
        print("links:")
        for link in video['links']:
            print(link)
        print()
# Out:
# VIDEOS WITH 'Shein':
# title: $1000+  BACK TO SCHOOL CLOTHING TRY ON HAUL| Princess Polly, SKIMS, Shein, etc
# links:
# https://youtu.be/WzSndjts7Dw
# https://instagram.com/ariyannahkelis_?igshid=YmMyMTA2M2Y=
# https://www.tiktok.com/@ariyannahkelis_?_t=8aY8dxmTLUQ&_r=1
# https://pin.it/7G7EwFl
# https://t.snapchat.com/JQio5MzB
# https://www.kulanikinis.com/
# https://m.westkiss.com/
# https://www.trulybeauty.com/discount/ARI20
# https://princesspolly.com/discount/CAMPUS20?rfsn=7132061.140d8d
# https://mytopicals.com/
# https://www.amazon.com/shop/ariyannah
#
# title: back to school clothing haul 2023| shein, savage x fenty, nike, abyl, + more!
# links:
# https://www.savagex.com/account/orderdetails/1387984560
# https://www.savagex.com/shop/trophy-wife-cheeky-sleep-short-sq2253335-5275-14044615?q=Island%20Print
# https://www.savagex.com/shop/liquid-metal-slip-sq2252359-7434-13764109?q=playtime%20pink
# https://us.shein.com/SHEIN-Qutie-Overlap-Waist-Space-Dye-Track-Shorts-p-12594414-cat-1912.html
# https://us.shein.com/Eyelash-Lace-Panel-Split-Hem-Cami-Night-Dress-p-3431939-cat-2209.html
# https://us.shein.com/SHEIN-Essnce-Mock-Neck-Split-Hem-Tank-Top-p-12808839-cat-1779.html
# https://us.shein.com/DAZY-Solid-Split-Hem-Patched-Drop-Shoulder-Tee-p-12232206-cat-1738.html
# https://us.shein.com/SHEIN-LUNE-Solid-Ruched-Side-Pencil-Hem-Tank-Dress-p-11456937-cat-1727.html
# https://us.shein.com/SHEIN-EZwear-Colorblock-Top-Stitching-Oversized-Tee-p-11437259-cat-1738.html
# https://us.shein.com/SHEIN-EZwear-Balletcore-Solid-Flare-Leg-Sweatpants-p-12713682-cat-2990.html
# links:
# https://www.savagex.com/account/orderdetails/1387984560
# https://www.savagex.com/shop/trophy-wife-cheeky-sleep-short-sq2253335-5275-14044615?q=Island%20Print
# https://www.savagex.com/shop/liquid-metal-slip-sq2252359-7434-13764109?q=playtime%20pink
# https://us.shein.com/SHEIN-Qutie-Overlap-Waist-Space-Dye-Track-Shorts-p-12594414-cat-1912.html
# https://us.shein.com/Eyelash-Lace-Panel-Split-Hem-Cami-Night-Dress-p-3431939-cat-2209.html
# https://us.shein.com/SHEIN-Essnce-Mock-Neck-Split-Hem-Tank-Top-p-12808839-cat-1779.html
# https://us.shein.com/DAZY-Solid-Split-Hem-Patched-Drop-Shoulder-Tee-p-12232206-cat-1738.html
# https://us.shein.com/SHEIN-LUNE-Solid-Ruched-Side-Pencil-Hem-Tank-Dress-p-11456937-cat-1727.html
# https://us.shein.com/SHEIN-EZwear-Colorblock-Top-Stitching-Oversized-Tee-p-11437259-cat-1738.html
# https://us.shein.com/SHEIN-EZwear-Balletcore-Solid-Flare-Leg-Sweatpants-p-12713682-cat-2990.html
# https://us.shein.com/SHEIN-Priv-Solid-Button-Front-Halter-Top-p-14519546-cat-1779.html
# https://us.shein.com/DAZY-Solid-Scoop-Neck-Ribbed-Knit-Tee-p-13425095-cat-1738.html
# https://us.shein.com/SHEIN-Essnce-Solid-Ruched-Hanky-Hem-Tank-Top-p-16897498-cat-1779.html
# https://us.shein.com/Lace-Trim-Cami-Night-Dress-p-9942774-cat-2209.html
# https://us.shein.com/SHEIN-EZwear-Solid-Wide-Leg-Sweatpants-p-14821615-cat-2990.html
# https://us.shein.com/SHEIN-Coolane-Drawstring-Waist-Flap-Pocket-Parachute-Pants-p-12712765-cat-1740.html
# https://us.shein.com/SHEIN-EZwear-Slogan-Graphic-Drop-Shoulder-Hoodie-p-4749617-cat-1773.html
# https://us.shein.com/Lace-Trim-Bow-Front-Split-Hem-Cami-Nightdress-p-10409367-cat-2209.htmL
# https://www.youtube.com/watch?v=Xtpo89ygO0k&t=20s
# https://www.youtube.com/watch?v=Wqf56ZeQWEM
# https://www.youtube.com/watch?v=mr_dUP20nWA&t=219s
# https://www.youtube.com/watch?v=Fna7TZawbMA
# https://www.youtube.com/watch?v=9GfDsMui2KI
# https://www.youtube.com/watch?v=KHoKOqV0lnk
# https://www.youtube.com/watch?v=M0ZkhQsBPAM
# https://www.youtube.com/watch?v=4v7zqcMuaEU
# https://www.instagram.com/piperharperr
# https://www.twitter.com/piperrharper
# https://www.snapchat.com/add/piper_jasmine
#
# title: back to school clothing haul 2023 👛🌼 (aritzia, princess polly, nike &amp; air 1 jordan lows)
# links:
# https://thmatc.co/?l=685FE87B
# https://thmatc.co/?l=DCA424A0
# https://thmatc.co/?l=60649951
# https://thmatc.co/?l=C831F068
# https://thmatc.co/?l=1E8321E7

# %%
youtube_data = []

# iterate over filtered videos and construct data for csv
for brand, vid_list in filtered_vids_brands.items():
    for video in vid_list:
        title = video['title']
        links = '\n'.join(video['links'])  
        youtube_data.append({'Brand': brand, 'Title': title, 'Links': links})

# create df
youtube_df = pd.DataFrame(youtube_data)

# export df to csv
youtube_df.to_csv('../data/filtered_videos.csv', index=False)
