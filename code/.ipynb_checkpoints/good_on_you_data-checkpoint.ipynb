# %% [markdown]
# # Getting ratings from a specific brand

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# import string

all_brand_info = []
cols = ['brand', 'overall_rating', 'planet_score', 'people_score', 'animals_score', 'description']

url = 'https://directory.goodonyou.eco/brand/'

brands = [
    'Princess Polly',
    'Brandy Melville',
    'Shein',
    'Nike',
    'Abercrombie & Fitch',
    'Amazon',
    'ASOS',
    'Forever 21', 
    'American Eagle'
]

for brand in brands:
    # convert brand name to url format
    brand_converted = brand.lower() # lowercase
    brand_converted = brand_converted.replace(' ', '-') # replace spaces with dashes
    brand_converted = brand_converted.replace('&', 'and') # replace '&' with 'and'
    # !! need to figure out a way to remove other punctuation like apostrophes (e.g., "Levi's") without removing the dashes we just added

    # get data on each brand's page
    response = requests.get(url+brand_converted)
    soup = BeautifulSoup(response.text, 'html.parser')

    # note: when finding classes on GOU's website, you might need to disable JavaScript (since BeautifulSoup can't load dynamic content)

    # get overall rating 
    overall_rating = soup.find('h6', class_='StyledHeading-sc-1rdh4aw-0 jNSEQB id__OverallRating-sc-12z6g46-7 cjSjNJ')
    overall_rating = overall_rating.text.split(': ')[1]

    # get subratings for planet, people, and animals
    subratings = soup.find_all('div', class_='id__RatingSingle-sc-12z6g46-9 ksJKxw')
 
    # remove category name from text 
    subratings[0] = subratings[0].text.split('Planet')[1]
    subratings[1] = subratings[1].text.split('People')[1]
    subratings[2] = subratings[2].text.split('Animals')[1]

    # if there's a rating, convert to int (makes it easier to analyze later)
    for i, rating in enumerate(subratings):
        if rating != 'Not applicable':
            subratings[i] = int(rating.split(' ')[0])

    # get description/justification
    text = soup.find('div', class_='id__BodyText-sc-12z6g46-15 eUqrmK').text
    
    # create new list of current brand info and add data
    brand_info = []
    brand_info.append(brand)
    brand_info.append(overall_rating)
    brand_info.append(subratings[0])
    brand_info.append(subratings[1])
    brand_info.append(subratings[2])
    brand_info.append(text)
    
    # add to overall list of brand info
    all_brand_info.append(brand_info)

brand_df = pd.DataFrame(all_brand_info, columns=cols)

# replace Good On You's categories with numerical ratings
# source: https://saturncloud.io/blog/how-to-convert-categorical-data-to-numerical-data-with-pandas
brand_df['overall_rating'] = brand_df['overall_rating'].replace({
    'We avoid': 1,
    'Not good enough': 2,
    "It's a start": 3,
    'Good': 4,
    'Great': 5
})

brand_df
# Out:
#                  brand  overall_rating  planet_score  people_score  \
# 0       Princess Polly               2             2             2
# 1      Brandy Melville               1             1             1
# 2                Shein               1             1             1
# 3                 Nike               3             3             3
# 4  Abercrombie & Fitch               2             2             2
# 5               Amazon               2             2             2
# 6                 ASOS               2             2             2
# 7           Forever 21               1             1             1
# 8       American Eagle               2             2             2
#
#    animals_score                                        description
# 0              4  Our “Planet” rating evaluates brands based on ...
# 1              0  This brand provides insufficient relevant info...
# 2              2  Our “Planet” rating evaluates brands based on ...
# 3              2  Our “Planet” rating evaluates brands based on ...
# 4              2  Abercrombie & Fitch is owned by Abercrombie Ab...
# 5              2  Amazon's rating applies to the Amazon house ap...
# 6              2  Our “Planet” rating evaluates brands based on ...
# 7              2  Forever 21 is owned by Authentic Brands Group....
# 8              2  American Eagle is owned by AEO Inc.Our “Planet...

# %%
# this CSV file is saved in the data folder
brand_df.to_csv('../data/brand_info.csv')

# %% [markdown]
# # Getting all brands from GOU's website and creating a dataset of their ratings

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://directory.goodonyou.eco/categories/tops' # so far it's the tops category only, will work more on this later

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

brands = soup.find_all('a', class_='Link__LinkBody-sc-o1cqd2-1 ijSNSa')
        
recommended = []

scraping_url = 'https://directory.goodonyou.eco'

for brand in brands:
    brand_name = brand.text
    brand_href = brand.get('href')
    if brand.text != '': # need this if statement because it's sometimes storing empty values for the name
        # get data on each brand's page
        response = requests.get(scraping_url+brand_href)
        soup = BeautifulSoup(response.text, 'html.parser')

        # get overall rating 
        overall_rating = soup.find('h6', class_='StyledHeading-sc-1rdh4aw-0 jNSEQB id__OverallRating-sc-12z6g46-7 cjSjNJ')
        overall_rating = overall_rating.text.split(': ')[1]
        
        # get subratings for planet, people, and animals
        subratings = soup.find_all('div', class_='id__RatingSingle-sc-12z6g46-9 ksJKxw')
        
        # remove category name from text 
        subratings[0] = subratings[0].text.split('Planet')[1]
        subratings[1] = subratings[1].text.split('People')[1]
        subratings[2] = subratings[2].text.split('Animals')[1]

        # if there's a rating, convert to int (makes it easier to analyze later)
        for i, rating in enumerate(subratings):
            if rating != 'Not applicable':
                subratings[i] = int(rating.split(' ')[0])

        # get description/justification
        text = soup.find('div', class_='id__BodyText-sc-12z6g46-15 eUqrmK').text

        # create new list of current brand info and add data
        brand_info = []
        brand_info.append(brand_name)
        brand_info.append(overall_rating)
        brand_info.append(subratings[0])
        brand_info.append(subratings[1])
        brand_info.append(subratings[2])
        brand_info.append(text)
        
        # add to overall list of brand info
        recommended.append(brand_info)

recommended_df = pd.DataFrame(recommended, columns=cols)

# replace Good On You's categories with numerical ratings
# source: https://saturncloud.io/blog/how-to-convert-categorical-data-to-numerical-data-with-pandas
recommended_df['overall_rating'] = recommended_df['overall_rating'].replace({
    'We avoid': 1,
    'Not good enough': 2,
    "It's a start": 3,
    'Good': 4,
    'Great': 5
})

recommended_df
# Out:
#                              brand  overall_rating  planet_score  \
# 0                      Yes Friends               5             5
# 1                   Monsoon Blooms               5             5
# 2                    Outland Denim               5             5
# 3                   STANLEY/STELLA               5             5
# 4                            ÉTICA               5             5
# 5                           Unrobe               5             5
# 6               Infantium Victoria               5             5
# 7                         ReCreate               5             5
# 8                           Subset               5             5
# 9                            Etiko               5             5
# 10        Where Does It Come From?               5             5
# 11                         éclipse               5             5
# 12                      Iron Roots               5             5
# 13                         Sealand               5             5
# 14                             non               5             5
# 15                       MUD Jeans               5             5
# 16                  Harvest & Mill               5             5
# 17                        Kalaurie               5             5
# 18  Ciganka - Artforms from Nature               5             5
# 19                            Rifò               5             5
# 20                           Dorsu               5             5
# 21                    Mantis World               5             4
# 22             The Standard Stitch               5             5
# 23             The Anjelms Project               5             5
# 24                     Dharma Bums               5             5
# 25                The R Collective               5             5
# 26                    Charlee Swim               5             5
# 27                      LA Relaxed               5             5
# 28                    Flare Street               5             4
# 29                        Tripulse               5             5
# 30                       SilkGenie               5             5
# 31                           amaud               5             5
# 32                           Joyya               5             4
# 33                       Mila.Vert               5             5
# 34                        Orbasics               5             5
# 35                            KOHR               5             5
# 36                        Mayamiko               5             5
# 37                       dk active               5             5
# 38                     People Tree               5             5
# 39              Mighty Good Basics               5             4
#
#     people_score   animals_score  \
# 0              5               5
# 1              5               5
# 2              5               5
# 3              4               5
# 4              5               5
# 5              5               5
# 6              4               5
# 7              5               4
# 8              4  Not applicable
# 9              5               5
# 10             5               4
# 11             4               5
# 12             5               5
# 13             4               5
# 14             4               5
# 15             4               5
# 16             4               5
# 17             5               4
# 18             5               4
# 19             4               4
# 20             5               4
# 21             4               5
# 22             4               5
# 23             5               4
# 24             5               5
# 25             5               4
# 26             4  Not applicable
# 27             4               5
# 28             5               5
# 29             4  Not applicable
# 30             5               4
# 31             5               4
# 32             5               4
# 33             4               4
# 34             4               4
# 35             4               5
# 36             5               4
# 37             4               5
# 38             5               4
# 39             5  Not applicable
#
#                                           description
# 0   Yes Friends' environment rating is 'great'. It...
# 1   Monsoon Blooms's environment rating is 'great'...
# 2   Our “Planet” rating evaluates brands based on ...
# 3   Our “Planet” rating evaluates brands based on ...
# 4   ÉTICA's environment rating is 'great'. It uses...
# 5   Unrobe's environment rating is 'great'. It use...
# 6   Our “Planet” rating evaluates brands based on ...
# 7   Our “Planet” rating evaluates brands based on ...
# 8   Our “Planet” rating evaluates brands based on ...
# 9   Our “Planet” rating evaluates brands based on ...
# 10  Where Does It Come From?'s environment rating ...
# 11  éclipse's environment rating is 'great'. It us...
# 12  Iron Roots's environment rating is 'great'. It...
# 13  Sealand's environment rating is 'great'. It us...
# 14  Our “Planet” rating evaluates brands based on ...
# 15  Our “Planet” rating evaluates brands based on ...
# 16  Harvest & Mill's environment rating is 'great'...
# 17  Kalaurie's environment rating is 'great'. It u...
# 18  Our “Planet” rating evaluates brands based on ...
# 19  Our “Planet” rating evaluates brands based on ...
# 20  Dorsu's environment rating is 'great'. It uses...
# 21  Mantis World's environment rating is 'good'. I...
# 22  The Standard Stitch's environment rating is 'g...
# 23  Our “Planet” rating evaluates brands based on ...
# 24  Dharma Bums's environment rating is 'great'. I...
# 25  The R Collective's environment rating is 'grea...
# 26  Charlee Swim's environment rating is 'great'. ...
# 27  Our “Planet” rating evaluates brands based on ...
# 28  Flare Street's environment rating is 'good'. I...
# 29  Our “Planet” rating evaluates brands based on ...
# 30  SilkGenie's environment rating is 'great'. It ...
# 31  Our “Planet” rating evaluates brands based on ...
# 32  Joyya's environment rating is 'good'. It uses ...
# 33  Our “Planet” rating evaluates brands based on ...
# 34  Orbasics's environment rating is 'great'. Its ...
# 35  KOHR's environment rating is 'great'. It uses ...
# 36  Our “Planet” rating evaluates brands based on ...
# 37  Our “Planet” rating evaluates brands based on ...
# 38  Our “Planet” rating evaluates brands based on ...
# 39  Mighty Good Basics's environment rating is 'go...

# %%
# this CSV file is saved in the data folder
recommended_df.to_csv('../data/gou_recommended.csv')
